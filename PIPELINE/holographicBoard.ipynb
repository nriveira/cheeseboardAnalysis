# %%
# Code for annotating the cheeseboard for metadata like:
# Reward coordinates, start box boundaries, reference distance for normalization
# Used to structure the data and log data for easier access.
# Functions:
# Loading in board
# Marking center of board for reference
# Setting reward locations
# Setting start box boundaries
# Setting reference distance for normalization

from experimentStruct import ExperimentStruct
from holographicBoard import HolographicBoard

# Load Data
timestamp = r'/Users/nick/Projects/cheeseboardAnalysis/DATA/FEBRUARY/1HourTrain/ExperimentVideo_2026-02-17_0950_timestamps.csv'
trial_data = ExperimentStruct(timestamp)
board = HolographicBoard(trial_data)
# Out:
# Video File: /Users/nick/Projects/cheeseboardAnalysis/DATA/FEBRUARY/1HourTrain/ExperimentVideo_2026-02-17_0950.mp4

# %%
board.show_board()

# %%
board.adjust_coordinates(-5,-10)
